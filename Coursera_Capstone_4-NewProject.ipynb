# %% [markdown]
# -------------------------------------------------
# -------------------------------------------------
#
# # Coursera Capstone Project Notebook (Part 3)
#
# [Link to Notebook (Part 1) of the project:](https://nbviewer.jupyter.org/gist/fy5std/1abce225f491d9471b80eca9edd8ae7c)
#
# ------------------------------------------------------
#
# ###     3. New Project - Where Do We Meet? WDWM

# %% [markdown]
# #### From Assignment
#
# This capstone project will be graded by your peers. This capstone project is worth *70%* of your total grade. The project will be completed over the course of 2 weeks. Week 1 submissions will be worth *30%* whereas week 2 submissions will be worth 40% of your total grade.
#
# ##### Week4
# For this week, you will required to submit the following:
#
# 1.   A description of the problem and a discussion of the background. **(15 marks)**
#
# 2.   A description of the data and how it will be used to solve the problem. **(15 marks)**
#
# ##### Week5
# This week, you will continue working on your capstone project. Please remember by the end of this week, you will need to submit the following:
#
# 1.  A full report consisting of all of the following components. **(15 marks)**:
#     * Introduction where you discuss the business problem and who would be interested in this project.
#     * Data where you describe the data that will be used to solve the problem and the source of the data.
#     * Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, and what machine learnings were used and why.
#     * Results section where you discuss the results.
#     * Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.
#     * Conclusion section where you conclude the report.
#
# 2. A link to your Notebook on your Github repository pushed showing your code. **(15 marks)**
#
# 3. Your choice of a presentation or blogpost. **(10 marks)**

# %% [markdown]
# ### Week 4

# %% [markdown]
# ### Background

# %% [markdown]
# We all have families, friends and business contacts around the country. Last decade we started to meet online, but meeting in a common place is always preferred, and sometimes is essential. In that case, the procedure depends on a few things;
#    * How far are the groups (3 km, 15 miles etc.),
#    * How is the transportation (by car, by public transportation etc.),
#    * Do groups have special needs/preferences in a meeting place (children, restaurant, disabled people etc.),
#    * Is there an appropriate place in between, within the transportation?
#
# Generally, after a quick assessment, the meeting place is chosen between known places. If the middle point is an unknown place or if a change on the meeting place is intended, then some search on the internet will help to determine the place
#
# In this frame, social interaction would be the main need to use this tool. Also, it would be used with business purposes such as finding a warehouse, store or maintenance place for stores in various places. So any individual user may be in a situation to use this tool. Specifically, we intend to specify the problem to a refugee (asylum seeker) group in Netherlands.

# %% [markdown]
# ### Problem Description

# %% [markdown]
# *The problem* we focus is about shortening the internet search time to filter appropriate places to meet.
#
# To be more precise, if two or more groups around the country intends to find an appropriate meeting point (children playground, hotel, restaurant, sports bar etc.) in a city in-between current locations, a tool which takes the current locations and gives the suggestions would help a lot.
#
# *The audience* in this project is AZC guests (refugees and asylum seekers). Since these people are new in the country, with no prior experience and lack of language, they generally struggle to find an appropriate place. Most of the guests don't even know their locations in the country (just know the name of AZC) and can not estimate a middle point to meet.

# %% [markdown]
# ### Data

# %% [markdown]
# In the described frame, I would like to find a solution to the probelem described above. So in Netherlands , there are community centers for refugees, called AZC. These centers are located all over Netherlands and people may move from one to another. When one wants to meet with a friend from another AZC, since the refugees would not have a car, she generally tries to find an in-between city, an appropriate place to meet and travel there by public transportation.
#
# So in this project, I will use the data from COA website (official AZC institution) to gather AZC locations. I will use foursquare data to find an appropriate place around intended meeting point.

# %% [markdown]
# ### Methodology (Projection)

# %% [markdown]
# First, I will download the [webpage](https://www.coa.nl/en/search-location), and then scrape it to reach the exact latitude and longitudes of AZC's (reception centers). Then I will use some temporary information to locate the current locations of the groups. Then, with a few equations, I intend to find a middle point with a radius large enough to a public transportation. Then lastly, after finding the approximate meeting point, I would use the foursquare data to list the categories and alternative places to meet.
#
# So let's move on.

# %% [markdown]
# ### Real World Data

# %% [markdown]
# ##### Import libraries and gather location data

# %%
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes
from bs4 import BeautifulSoup
import csv
import requests

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

print('Basic Database, WebScrape, JSON Libraries imported.')
# Out:
# Basic Database, WebScrape, JSON Libraries imported.

# %%
source = requests.get('https://www.coa.nl/en/search-location').text
soup = BeautifulSoup(source, 'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="https://www.coa.nl/sites/www.coa.nl/themes/coa_bs/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <meta content="Approximately one-sixth of the Dutch municipalities now have a COA asylum centre. In some municipalities there are several reception locations, for example an azc and a process reception centre. Most reception locations are regular asylum seekers' centres." name="description"/>
#   <meta content="Drupal 7 (https://www.drupal.org)" name="generator"/>
#   <link href="https://www.coa.nl/en/search-location" rel="canonical"/>
#   <link href="https://www.coa.nl/en/node/278" rel="shortlink"/>
#   <title>
#    Search location | www.coa.nl
#   </title>
#   <link href="https://www.coa.nl/sites/www.coa.nl/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.coa.nl/sites/www.coa.nl/files/css/css_Q7R7Blo9EYqLDI5rIlO_T3uTFBjIXjLpcqMHjTvVdmg.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.coa.nl/sites/www.coa.nl/files/css/css_3ulr6cEQXsEv68j1Jtdw7v5zxlXyzIaqEWKYeX9_WxE.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.coa.nl/sites/www.coa.nl/files/css/css_Ll-rZMwGIXIGT44k8b-7C3lAsCfHgMUUsjrXTvgNmY8.css" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if lte IE 8]>
# <link type="text/css" rel="stylesheet" href="https://www.coa.nl/sites/www.coa.nl/files/css/css_47DEQpj8HBSa-_TImW-5JCeuQeRkm5NMpJWZG3hSuFU.css" media="all" />
# <![endif]-->
#   <link href="https://www.coa.nl/sites/www.coa.nl/files/css/css_4nG9iEdBULHnUCzZ7ZpBaZA2eoJB0j1XsF1oGM95g0k.css" media="all" rel="stylesheet" type="text/css"/>
#   <style>
#    #sliding-popup.sliding-popup-bottom,#sliding-popup.sliding-popup-bottom .eu-cookie-withdraw-banner,.eu-cookie-withdraw-tab{background:#0779BF;}#sliding-popup.sliding-popup-bottom.eu-cookie-withdraw-wrapper{background:transparent}#sliding-popup .popup-content #popup-text h1,#sliding-popup .popup-content #popup-text h2,#sliding-popup .popup-content #popup-text h3,#sliding-popup .popup-content #popup-text p,.eu-cookie-compliance-more-button,.eu-cookie-compliance-secondary-button,.eu-cookie-withdraw-tab{color:#ffffff !important;}.eu-cookie-withdraw-tab{border-color:#ffffff;}
#   </style>
#   <link href="https://www.coa.nl/sites/www.coa.nl/files/css/css_TbuqO3JUELhJ216MSWMIF9dyxiVrUgU65TxJPp4gZSI.css" media="all" rel="stylesheet" type="text/css"/>
#   <!-- HTML5 element support for IE6-8 -->
#   <!--[if lt IE 9]>
#     <script src="https://cdn.jsdelivr.net/html5shiv/3.7.3/html5shiv-printshiv.min.js"></script>
#   <![endif]-->
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_xvYJgU6LChHqbcSh4y1AvdXfD5QBIwT3GVGVUeuksbM.js">
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_WxaUmOcUBCpsyhtIKLDAP8PKr6BePwt78ksCvXQbPnE.js">
#   </script>
#   <script>
#    L_ROOT_URL = "/sites/all/libraries/leaflet/";
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_jmU1htzFfP3qANfs1TfNOvyS-Sj57ZBlN6CvphjSv18.js">
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_EywSM5hrR_hVHAsy4dHTQeb-7t21KoDdPwh-IQXUZCQ.js">
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_-Odpv3ZXP9IrVSWQ4KWbZhEPNIMcuxRms11ANkgvjtE.js">
#   </script>
#   <script>
#    L.Icon.Default.imagePath = "/sites/all/libraries/leaflet/images/";
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_3m3H02PTs0p5jEFe0ZGVGJDbv6OXJ99PSu5L-qHwc1s.js">
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_UKeb9XvdsJdp0Xk5Ura1DMHduxgD1CiKcFlYreeiDdI.js">
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_OLgr-593LYCzF1vZ05PpqLNjLgPEsdxeuLPiASPOib8.js">
#   </script>
#   <script>
#    jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"en\/","ajaxPageState":{"theme":"coa_bs","theme_token":"4TSS-8jlG_1hsP2HNwN7ShJlxABFLorp9Yb6og8dNis","jquery_version":"1.10","js":{"0":1,"1":1,"2":1,"sites\/www.coa.nl\/modules\/coa_leaflet\/js\/coa_leaflet.js":1,"sites\/www.coa.nl\/themes\/bootstrap\/js\/bootstrap.js":1,"sites\/all\/modules\/eu_cookie_compliance\/js\/eu_cookie_compliance.js":1,"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.10\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.core.min.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.widget.min.js":1,"sites\/all\/modules\/eu_cookie_compliance\/js\/jquery.cookie-1.4.1.min.js":1,"sites\/all\/modules\/jquery_update\/replace\/misc\/jquery.form.min.js":1,"3":1,"sites\/all\/libraries\/leaflet\/leaflet.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.accordion.min.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/fancy_file_delete\/js\/fancyfiledelete.js":1,"sites\/all\/modules\/extlink\/extlink.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox_load.js":1,"sites\/all\/modules\/ctools\/js\/auto-submit.js":1,"sites\/all\/modules\/views\/js\/base.js":1,"sites\/www.coa.nl\/themes\/bootstrap\/js\/misc\/_progress.js":1,"sites\/all\/modules\/views\/js\/ajax_view.js":1,"sites\/all\/modules\/leaflet\/leaflet.drupal.js":1,"4":1,"sites\/all\/modules\/views_accordion\/views-accordion.js":1,"sites\/all\/modules\/ctools\/js\/jump-menu.js":1,"sites\/all\/modules\/matomo\/matomo.js":1,"sites\/all\/modules\/field_group\/field_group.js":1,"sites\/all\/modules\/colorbox_node\/colorbox_node.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/affix.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/alert.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/button.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/carousel.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/collapse.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/dropdown.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/modal.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/tooltip.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/popover.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/scrollspy.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/tab.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/bootstrap\/js\/transition.js":1,"sites\/www.coa.nl\/themes\/coa_bs\/js\/script.js":1,"sites\/www.coa.nl\/themes\/bootstrap\/js\/modules\/views\/js\/ajax_view.js":1,"sites\/www.coa.nl\/themes\/bootstrap\/js\/misc\/ajax.js":1},"css":{"modules\/system\/system.base.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.accordion.css":1,"sites\/all\/modules\/colorbox_node\/colorbox_node.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/video_filter\/video_filter.css":1,"sites\/all\/modules\/extlink\/extlink.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/leaflet\/leaflet_extras.css":1,"sites\/all\/libraries\/leaflet\/leaflet.css":1,"sites\/all\/libraries\/leaflet\/leaflet.ie.css":1,"sites\/all\/modules\/eu_cookie_compliance\/css\/eu_cookie_compliance.css":1,"public:\/\/icon\/icomoon\/coa\/style.css":1,"0":1,"sites\/www.coa.nl\/themes\/coa_bs\/css\/style.css":1,"sites\/www.coa.nl\/themes\/coa_bs\/css\/quickfix.css":1}},"col ...
#   </script>
#  </head>
#  <body class="navbar-is-fixed-top html not-front not-logged-in one-sidebar sidebar-second page-node page-node- page-node-278 node-type-pagina i18n-en">
#   <div id="skip-link">
#    <a class="element-invisible element-focusable" href="#main-content">
#     Skip to main content
#    </a>
#   </div>
#   <header class="navbar navbar-fixed-top navbar-default" id="navbar" role="banner">
#    <div class="container top-header-bar">
#     <div class="col-xs-3 col-lg-6 col-md-6 pull-left">
#      <div class="navbar-header">
#       <a class="logo hidden-xs navbar-btn pull-left" href="/en" title="Home">
#        <img alt="Home" src="https://www.coa.nl/sites/www.coa.nl/files/logo_25_jaar_coa.png"/>
#       </a>
#       <a class="logo visible-xs navbar-btn pull-left" href="/en" title="Home">
#        <img alt="Home" src="/sites/www.coa.nl/themes/coa_bs/logo-s.png"/>
#       </a>
#      </div>
#     </div>
#     <div class="col-xs-9 col-lg-6 col-md-6 pull-right">
#      <div class="region region-top-settings">
#       <div id="block-menu-menu-secundair-menu">
#        <section class="block block-coa-locale pull-right clearfix" id="block-coa-locale-coa-locale">
#         <ul class="menu nav">
#          <li class="first leaf">
#           <a href="/en" title="">
#            Home
#           </a>
#          </li>
#          <li class="last leaf">
#           <a href="https://www.coa.nl/nl/zoek-locatie" id="coa_locale_menu_path_fallback_nl">
#            Nederlands
#           </a>
#          </li>
#         </ul>
#        </section>
#       </div>
#      </div>
#      <div class="visible-xs" id="langmob">
#       <a href="/nl">
#        <img src="/sites/www.coa.nl/themes/coa_bs/images/nl.png"/>
#       </a>
#      </div>
#      <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-burger-ui">
#       </span>
#      </button>
#     </div>
#    </div>
#    <div class="container sub-header-bar">
#     <div class="col-lg-9 col-md-10 col-xs-12">
#      <div class="navbar-collapse collapse">
#       <nav role="navigation">
#        <ul class="menu nav navbar-nav">
#         <li class="first leaf">
#          <a href="/en/reception-of-asylum-seekers-0">
#           Asylum
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="/en/reception-centres-0">
#           Reception centres
#          </a>
#         </li>
#         <li class="leaf active-trail active">
#          <a class="active-trail active" href="/en/search-location">
#           Locations
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="/en/about-coa">
#           About COA
#          </a>
#         </li>
#         <li class="last leaf">
#          <a href="/en/contact">
#           Contact
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#     <div class="col-lg-3 col-md-2 col-xs-4 pull-right">
#      <div class="region region-sub-nav-box">
#       <section class="block block-search clearfix" id="block-search-form">
#        <form accept-charset="UTF-8" action="/en/search-location" class="form-search content-search" id="search-block-form" method="post">
#         <div>
#          <div>
#           <h2 class="element-invisible">
#            Search form
#           </h2>
#           <div class="input-group">
#            <input class="form-control form-text" id="edit-search-block-form--2" maxlength="128" name="search_block_form" placeholder="Search" size="15" title="Enter the terms you wish to search for." type="text" value=""/>
#            <span class="input-group-btn">
#             <button class="btn btn-primary" type="submit">
#             </button>
#            </span>
#           </div>
#           <div class="form-actions form-wrapper form-group" id="edit-actions">
#            <button class="element-invisible btn btn-primary form-submit" id="edit-submit" name="op" type="submit" value="Search">
#             Search
#            </button>
#           </div>
#           <input name="form_build_id" type="hidden" value="form-dDkIPlvqy2DjEdHpr_W2tGar14j1FPvPvIe1qYqY7-I"/>
#           <input name="form_id" type="hidden" value="search_block_form"/>
#          </div>
#         </div>
#        </form>
#       </section>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="highlight-container container full-width">
#    <div class="region region-slide">
#     <section class="block block-views clearfix" id="block-views-slide-block">
#      <div class="view view-slide view-id-slide view-display-id-block view-dom-id-ce9499c0141b2a24e77e99ba6d69a7b1">
#       <div class="view-content">
#        <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#         <div class="views-field views-field-field-head-slide">
#          <div class="field-content">
#           <div class="field-collection-view clearfix view-mode-full field-collection-view-final">
#            <div class="entity entity-field-collection-item field-collection-item-field-head-slide clearfix">
#             <div class="content">
#              <div class="field field-name-field-slide field-type-image field-label-hidden img-responsive">
#               <div class="field-items">
#                <div class="field-item even">
#                 <img alt="" class="img-responsive" height="460" src="https://www.coa.nl/sites/www.coa.nl/files/styles/kop-full/public/slide/azc_dronten714_cropped_0.jpg?itok=YTNB_wK1" width="1200"/>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#    </div>
#    <ol class="breadcrumb">
#     <li>
#      <span class="active active-trail">
#       Search location
#      </span>
#     </li>
#    </ol>
#   </div>
#   <div class="main-container container">
#    <header id="page-header" role="banner">
#    </header>
#    <!-- /#page-header -->
#    <div class="row main-wrapper">
#     <section class="col-sm-7 col-md-7 col-lg-8 main-content">
#      <a id="main-content">
#      </a>
#      <h1 class="page-header">
#       <span aria-hidden="true" class="icon icomoon coa-location2">
#       </span>
#       Search location
#      </h1>
#      <div class="region region-content">
#       <section class="block block-system clearfix" id="block-system-main">
#        <article class="node node-pagina clearfix" id="node-278">
#         <div class="field field-name-body field-type-text-with-summary field-label-hidden">
#          <div class="field-items">
#           <div class="field-item even">
#            <p>
#             Approximately one-sixth of the Dutch municipalities now have a COA asylum centre. In some municipalities there are several reception locations, for example an azc and a process reception centre. Most reception locations are regular asylum seekers' centres.
#            </p>
#            <p>
#             In 2017, the total capacity for the central reception of asylum seekers was reduced to 31,000 available places spread over approximately 60 locations. In 2018, the COA will again take measures to bring the available reception capacity into balance with the expected inflow and outflow of asylum seekers. The COA will close 11 locations this year; 51 reception locations will remain open.
#            </p>
#            <h2>
#             Closed reception centres
#            </h2>
#            <p>
#             The map of the Netherlands below shows all COA locations where asylum seekers reside. The COA also manages a number of locations that are not inhabited. These locations have been closed due to the low inflow of asylum seekers, but the agreements with the municipality and / or letter are still on-going. In some cases, the COA owns the property.
#            </p>
#           </div>
#          </div>
#         </div>
#        </article>
#       </section>
#       <section class="block block-views clearfix" id="block-views-locaties-blok-groot-leaflet">
#        <h2 class="block-title">
#         Filter locations
#        </h2>
#        <div class="view view-locaties view-id-locaties view-display-id-blok_groot_leaflet view-dom-id-89d8c29e9f3ecb6e6db9ccc51afc72dd">
#         <div class="view-filters">
#          <form accept-charset="UTF-8" action="/en" class="ctools-auto-submit-full-form" id="views-exposed-form-locaties-blok-groot-leaflet" method="get">
#           <div>
#            <div class="views-exposed-form">
#             <div class="views-exposed-widgets clearfix">
#              <div class="views-exposed-widget views-widget-filter-field_type_locatie_tid" id="edit-field-type-locatie-tid-wrapper">
#               <label for="edit-field-type-locatie-tid">
#                Type of location
#               </label>
#               <div class="views-widget">
#                <div class="form-item form-item-field-type-locatie-tid form-type-select form-group">
#                 <select class="form-control form-select" id="edit-field-type-locatie-tid" name="field_type_locatie_tid">
#                  <option selected="selected" value="All">
#                   - Any -
#                  </option>
#                  <option value="1">
#                   Opvanglocatie
#                  </option>
#                  <option value="202">
#                   -Alleenstaande minderjarige vreemdelingen
#                  </option>
#                  <option value="201">
#                   -Asielzoekerscentrum (azc)
#                  </option>
#                  <option value="199">
#                   -Centrale ontvangstlocatie (col)
#                  </option>
#                  <option value="243">
#                   -Extra begeleiding en toezichtlocatie
#                  </option>
#                  <option value="205">
#                   -Gesloten gezinslocatie
#                  </option>
#                  <option value="203">
#                   -Gezinslocatie
#                  </option>
#                  <option value="200">
#                   -Procesopvanglocatie (pol)
#                  </option>
#                  <option value="204">
#                   -Vrijheidsbeperkende locatie
#                  </option>
#                 </select>
#                </div>
#               </div>
#              </div>
#              <div class="views-exposed-widget views-submit-button">
#               <button class="ctools-use-ajax ctools-auto-submit-click js-hide btn btn-primary form-submit" id="edit-submit-locaties" name="" type="submit" value="Filteren">
#                Filteren
#               </button>
#              </div>
#             </div>
#            </div>
#           </div>
#          </form>
#         </div>
#         <div class="view-content">
#          <div id="leaflet-map-1473650142" style="height: 400px">
#          </div>
#         </div>
#        </div>
#       </section>
#       <section class="block block-views clearfix" id="block-views-trefwoorden-block">
#        <div class="view view-trefwoorden view-id-trefwoorden view-display-id-block view-dom-id-3692b2afe1fda913f04279a510b7074f">
#         <div class="view-content">
#          <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#          </div>
#         </div>
#        </div>
#       </section>
#      </div>
#     </section>
#     <aside class="col-sm-5 col-md-5 col-lg-4" role="complementary">
#      <div class="region region-sidebar-second">
#       <section class="block block-views blue-content blue-header clearfix" id="block-views-locaties-locatie-dropdown">
#        <h2 class="block-title">
#         Reception centres
#        </h2>
#        <div class="view view-locaties view-id-locaties view-display-id-locatie_dropdown blue-content blue-header view-dom-id-ffc9f8283bbf60d336fbf087861df78b">
#         <div class="view-content">
#          <form accept-charset="UTF-8" action="/en/search-location" id="ctools-jump-menu" method="post">
#           <div>
#            <div class="container-inline">
#             <div class="form-item form-item-jump form-type-select form-group">
#              <select class="ctools-jump-menu-select ctools-jump-menu-change form-control form-select" id="edit-jump" name="jump">
#               <option selected="selected" value="">
#                - Choose a location -
#               </option>
#               <option value="c755844cf0184f78f440f270b448479b::/en/node/1889">
#                Almelo - Vriezenveenseweg 170
#               </option>
#               <option value="f71edff724d5753c0eb1f6c27d89558d::/en/node/28">
#                Almelo - Vriezenveenseweg 170a
#               </option>
#               <option value="ced9d79048c272594ae5e9894bf34fc1::/en/node/379">
#                Almere
#               </option>
#               <option value="7ac6a5ed98d41aebe912554292e77e7f::/en/node/596">
#                Amersfoort
#               </option>
#               <option value="56baf238601fcd3a1aab06965a283d97::/en/amsterdam-transformatorweg">
#                Amsterdam - Transformatorweg
#               </option>
#               <option value="84bc78b6ca64bc76be8c9ede30e8246a::/en/zoek-locatie/amsterdam-willinklaan">
#                Amsterdam - Willinklaan
#               </option>
#               <option value="f2ecdb42d6a55fa2e59d8a7b3cda132a::/en/apeldoorn">
#                Apeldoorn
#               </option>
#               <option value="f0f1e67b43124b45abd6ccf29beb4f45::/en/node/1472">
#                Arnhem - Apeldoornseweg
#               </option>
#               <option value="0c71b1cf0d8b7309ccc0aa97967d3095::/en/node/1544">
#                Arnhem - Elderhofseweg
#               </option>
#               <option value="44c9d3945c286dbb7ba6879933cd76bd::/en/node/1812">
#                Arnhem - Frombergstraat
#               </option>
#               <option value="e2a7c6489f384043a4cbd01046b48372::/en/node/441">
#                Arnhem-Zuid - Vreedenburgh
#               </option>
#               <option value="5ea683d3c946ba283812c491164d7fa4::/en/node/1550">
#                Assen
#               </option>
#               <option value="0af6a23a5bfa8da0a77088c13ced374e::/en/node/255">
#                Baexem
#               </option>
#               <option value="395e564aee8a0f658ff26e5e04fe6fd2::/en/node/884">
#                Budel-Cranendonck
#               </option>
#               <option value="b72d58fa58ef52fccd8a617402f2c6de::/en/node/25">
#                Burgum
#               </option>
#               <option value="96e43ac12b2fd7941c87ec48be70e5b7::/en/node/308">
#                Delfzijl
#               </option>
#               <option value="21c4bee2155bf7ca4349512ba8270b83::/en/node/1216">
#                Den Helder Burgemeester Ritmeesterweg
#               </option>
#               <option value="1959d729bdd3d21049b99296a7fd6ac1::/en/node/2148">
#                Den Helder Nieuweweg
#               </option>
#               <option value="2911ae05ccea0e4f82887d9a34c765aa::/en/node/26">
#                Drachten - Noorderend
#               </option>
#               <option value="9a767a636ea81b774ca379f1c29239a2::/en/node/1801">
#                Drachten - Ringweg
#               </option>
#               <option value="559ff88a333e96aca99bf42fa895433e::/en/node/375">
#                Dronten
#               </option>
#               <option value="a8b6fdc261fa8a4f3d5f27a839a2f456::/en/node/245">
#                Echt
#               </option>
#               <option value="012187dd12605193b9ceb9437002a4c7::/en/node/29">
#                Emmen
#               </option>
#               <option value="84ac07426197bbcbcdb55e4251ac8262::/en/node/236">
#                Gilze en Rijen
#               </option>
#               <option value="a2a1f75a8ba042e5c5df3f1ba6b61b65::/en/node/301">
#                Goes
#               </option>
#               <option value="5403cb3329559e448890f0a5f6a76539::/en/node/303">
#                Grave
#               </option>
#               <option value="edbc63f9af62f18aac3feec8a158267c::/en/node/1369">
#                's-Gravendeel
#               </option>
#               <option value="88cf9ed52f3fcaec59145bcdee5c35a7::/en/node/1723">
#                Hardenberg
#               </option>
#               <option value="72c9abc395ac1912c912c85265ec64bb::/en/node/1725">
#                Harderwijk
#               </option>
#               <option value="babe4b10eca587b65de670d6e32fe6db::/en/node/1217">
#                Heerhugowaard
#               </option>
#               <option value="fd50b8cfc0f8c138c728b303d89ad8c7::/en/node/246">
#                Heerlen
#               </option>
#               <option value="4f9dbc57e2f85a68c2282fbbebf4a1b6::/en/zoek-locatie/hengelo-hooghagen">
#                Hengelo
#               </option>
#               <option value="9a057e621059ee01ca13a4a19a19cde0::/en/node/1133">
#                Hoogeveen
#               </option>
#               <option value="b32a1c96b94d0acccdca14c11dc12d0e::/en/node/1806">
#                Kampen
#               </option>
#               <option value="d6ee77b4c053fa331c1d1c506c956717::/en/node/310">
#                Katwijk
#               </option>
#               <option value="a7af81322c58a045d2dd3c612e52f0b9::/en/node/312">
#                Leersum
#               </option>
#               <option value="1ee18473d492bf65e64aa0354a3718ce::/en/node/377">
#                Luttelgeest
#               </option>
#               <option value="ed8dcc173bfc12546b0cfc37d4d4fcea::/en/maastricht-parkweg">
#                Maastricht - Parkweg
#               </option>
#               <option value="48458cf3152395a5c76ab4f0d553841a::/en/node/1187">
#                Middelburg
#               </option>
#               <option value="cae405f4ff4963ac43e56a527866af07::/en/node/437">
#                Nijmegen - Dommer van Poldersveldtweg
#               </option>
#               <option value="4fcf005dba0b4578a4e0c21c92d53d01::/en/node/240">
#                Oisterwijk
#               </option>
#               <option value="38be21ca61e22b2f049604dd576150ef::/en/node/900">
#                Overloon
#               </option>
#               <option value="5e1eb087f6049e56ce112544469effb5::/en/node/1726">
#                Rijswijk
#               </option>
#               <option value="b60d6c0d616f22796566da5364f04ea7::/en/node/1690">
#                Rotterdam
#               </option>
#               <option value="e4c5cadcaad15e35c4e85ada31b5405b::/en/node/31">
#                Schalkhaar
#               </option>
#               <option value="ff046812e354c8f61cb6d7d957080cac::/en/node/27">
#                Sint Annaparochie
#               </option>
#               <option value="e1ada112ba237b382c9cc291df457a80::/en/node/1772">
#                Sneek
#               </option>
#               <option value="0b93f1074453f30bc0065555bae2d4b1::/en/node/792">
#                Sweikhuizen
#               </option>
#               <option value="e102ca3ab770069e6448c3596387cec9::/en/node/435">
#                Ter Apel
#               </option>
#               <option value="59dd2c729d6afd66bc7ae520fd927e78::/en/node/1877">
#                Tilburg - Baden Powellaan
#               </option>
#               <option value="d025c635cacc8f826ec6fc72f16f193c::/en/node/1819">
#                Tilburg - Stationsstraat
#               </option>
#               <option value="3a52feafc38a4904e8944b24c9f1d2c4::/en/node/1770">
#                Utrecht - Guesthouse
#               </option>
#               <option value="cd3f11746137b62d0353cf895df2a848::/en/node/315">
#                Utrecht - Joseph Haydnlaan
#               </option>
#               <option value="a81252dea3e690686752434cc2081ebd::/en/node/1778">
#                Wageningen - Bosrandweg
#               </option>
#               <option value="e107019a7a548e28974ee1701dbf648b::/en/node/321">
#                Wageningen - Keijenbergseweg
#               </option>
#               <option value="e256afcc77c2cd96d279bf463b2b2b1b::/en/node/1045">
#                Wassenaar
#               </option>
#               <option value="60d37238d0009afdfd4203a54e7ca022::/en/node/1251">
#                Weert
#               </option>
#               <option value="0af8fae27093b0efbc042dad0eaf5a32::/en/node/445">
#                Winterswijk
#               </option>
#               <option value="d4cc3616bf8c413685a7a9165cd76897::/en/node/1602">
#                Zutphen
#               </option>
#               <option value="d48dc1fc04c3fed495aab756ac5da45f::/en/node/306">
#                Zweeloo
#               </option>
#              </select>
#             </div>
#             <button class="ctools-jump-menu-button ctools-jump-menu-hide btn btn-default form-submit" id="edit-go" name="op" type="submit" value="Gaan">
#              Gaan
#             </button>
#            </div>
#            <input name="form_build_id" type="hidden" value="form-mb3k9abToevUICAWIFpS35TAQfG8bYojgNBmiv2O7t4"/>
#            <input name="form_id" type="hidden" value="ctools_jump_menu"/>
#           </div>
#          </form>
#         </div>
#        </div>
#       </section>
#       <section class="block block-views clearfix" id="block-views-terzijde-blok">
#        <div class="view view-terzijde view-id-terzijde view-display-id-blok view-dom-id-efceac56f649172dd550a5747d0506b6">
#         <div class="view-content">
#          <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#           <div class="views-field views-field-field-terzijde">
#            <div class="field-content">
#             <p>
#              <span>
#               On
#              </span>
#              <a href="https://www.coa.nl/mycoa/en">
#               <span>
#                MyCOA
#               </span>
#              </a>
#              <span>
#               , the website for the residents, each location has its own page containing
#              </span>
#              <span>
#               information about the location itself and practical information about, for example, public transport, shops and other facilities in the immediate vicinity
#              </span>
#              <span>
#               .
#              </span>
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#       <section class="block block-views blue-content blue-header clearfix" id="block-views-media-links-rechts-blok">
#        <h2 class="block-title">
#         Links
#        </h2>
#        <div class="view view-media-links-rechts view-id-media_links_rechts view-display-id-blok lijst view-dom-id-f7c230b3ebe3953d1ea4f9fe8d9742ea">
#         <div class="view-content">
#          <div class="views-row views-row-1 views-row-odd views-row-first">
#           <div class="views-field views-field-field-media-links">
#            <div class="field-content">
#             <a href="https://www.coa.nl/en/reception-of-asylum-seekers/living-at-an-asylum-seekers-centre">
#              Living at an asylum seekers’ centre
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="views-row views-row-2 views-row-even">
#           <div class="views-field views-field-field-media-links">
#            <div class="field-content">
#             <a href="https://www.coa.nl/en/reception-centres/types-of-reception-centres">
#              Types of reception centres
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="views-row views-row-3 views-row-odd views-row-last">
#           <div class="views-field views-field-field-media-links">
#            <div class="field-content">
#             <a href="https://www.coa.nl/en/reception-centres/opening-and-closing">
#              Opening and closing
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#      </div>
#     </aside>
#     <!-- /#sidebar-second -->
#    </div>
#   </div>
#   <footer class="footer container">
#    <div class="region region-footer">
#     <section class="block block-menu col-sm-4 has-icon clearfix" id="block-menu-menu-partners-en">
#      <div class="block-header">
#       <h2 class="block-title">
#        <span aria-hidden="true" class="icon icomoon coa-more">
#        </span>
#        Partners
#       </h2>
#      </div>
#      <div class="bloklichaam lichaam partner">
#       <ul class="menu nav">
#        <li class="first leaf">
#         <a href="https://ind.nl/en?pk_campaign=header&amp;pk_kwd=taal-selectie-en">
#          Immigration and Naturalisation Service (IND)
#         </a>
#        </li>
#        <li class="leaf">
#         <a href="http://english.dienstterugkeerenvertrek.nl/">
#          Repatriation and Departure Service  (DT&amp;V)
#         </a>
#        </li>
#        <li class="leaf">
#         <a href="http://www.vluchtelingenwerk.nl/english/english.php">
#          Dutch Council for Refugees
#         </a>
#        </li>
#        <li class="leaf">
#         <a href="https://www.nidos.nl/en/">
#          Nidos Foundation
#         </a>
#        </li>
#        <li class="last leaf">
#         <a href="http://www.iom-nederland.nl/en/">
#          International Organization for Migration
#         </a>
#        </li>
#       </ul>
#      </div>
#     </section>
#     <section class="block block-menu col-sm-4 has-icon clearfix" id="block-menu-menu-shortcuts-en">
#      <div class="block-header">
#       <h2 class="block-title">
#        <span aria-hidden="true" class="icon icomoon coa-more">
#        </span>
#        Shortcuts
#       </h2>
#      </div>
#      <div class="bloklichaam lichaam shortcuts">
#       <ul class="menu nav">
#        <li class="first leaf">
#         <a href="https://www.coa.nl/sites/www.coa.nl/files/documenten/privacyverklaring-coa_engels.pdf">
#          Privacy
#         </a>
#        </li>
#        <li class="last leaf">
#         <a href="/en/Node/325">
#          Contact
#         </a>
#        </li>
#       </ul>
#      </div>
#     </section>
#     <!-- /.block -->
#     <section class="block block-bean col-sm-4 has-icon clearfix" id="block-bean-bean-contact-en">
#      <div class="block-header">
#       <h2 class="block-title">
#        <span aria-hidden="true" class="icon icomoon coa-more">
#        </span>
#        Contact
#       </h2>
#      </div>
#      <div class="bloklichaam lichaam contact">
#       <div class="entity entity-bean bean-tekstblok clearfix">
#        <div class="content">
#         <div class="field field-name-field-tekstveld field-type-text-long field-label-hidden">
#          <div class="field-items">
#           <div class="field-item even">
#            <p>
#             <strong>
#              Postal address
#             </strong>
#             <br/>
#             Centraal Orgaan opvang asielzoekers
#             <br/>
#             Postbus 30203
#             <br/>
#             2500 GE Den Haag
#             <br/>
#             The Netherlands
#             <br/>
#             T +31 (0)88-7157000
#            </p>
#            <p>
#             <strong>
#              Visiting address
#             </strong>
#             <br/>
#             Rijnstraat 8
#             <br/>
#             2515 XP Den Haag
#            </p>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <!-- /.block -->
#    </div>
#   </footer>
#   <script>
#    function euCookieComplianceLoadScripts() {}
#   </script>
#   <script>
#    var eu_cookie_compliance_cookie_name = "";
#   </script>
#   <script>
#    var _paq = _paq || [];(function(){var u=(("https:" == document.location.protocol) ? "https://piwik.coa.nl/" : "https://piwik.coa.nl/");_paq.push(["setSiteId", "1"]);_paq.push(["setTrackerUrl", u+"piwik.php"]);_paq.push(["setDoNotTrack", 1]);_paq.push(["trackPageView"]);_paq.push(["setIgnoreClasses", ["no-tracking","colorbox"]]);_paq.push(["enableLinkTracking"]);var d=document,g=d.createElement("script"),s=d.getElementsByTagName("script")[0];g.type="text/javascript";g.defer=true;g.async=true;g.src=u+"piwik.js";s.parentNode.insertBefore(g,s);})();
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_vr47U2IVHvT5wHVR89HrRvg3oRmf6TUAcJmhyfPVLZI.js">
#   </script>
#   <script src="https://www.coa.nl/sites/www.coa.nl/files/js/js_Shjb7FZMah24N0P8JH6K8QId9f9srs1jRErgv2-M2tA.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# This is the full wabpage, and there are location information inside, but since it was written in Java it's complicated to reach the location info with an automated process. I think it would be easier to scrape the information with a text editor using regex.

# %%
f = csv.writer(open("COA_Web.csv", "w"))
f.writerow([soup])
# Out:
# 59853

# %% [markdown]
# I did some regex edits with Sublime Text on the csv file for faster process. Now the file contains lat-long of the AZC (Name).

# %% [markdown]
# ##### Convert the data to dataframe

# %%
df_coa = pd.read_csv('coa_site_scrapped2.csv')
print(df_coa)
# Out:
#     Latitude  Longitude                                   Name
# 0    51.4948    3.59212                             Middelburg
# 1    51.4966    3.87917                                   Goes
# 2    52.0337    4.32979                               Rijswijk
# 3    52.1460    4.38730                              Wassenaar
# 4    52.1774    4.41329                                Katwijk
# 5    51.8850    4.56808                              Rotterdam
# 6    51.7612    4.62215                           s-Gravendeel
# 7    52.9321    4.75435  Den Helder Burgemeester Ritmeesterweg
# 8    52.3716    4.80231                Amsterdam - Willinklaan
# 9    52.6775    4.84204                          Heerhugowaard
# 10   52.3935    4.86152           Amsterdam - Transformatorweg
# 11   51.5346    4.90282                         Gilze en Rijen
# 12   51.5594    5.08258               Tilburg - Stationsstraat
# 13   52.0830    5.08572             Utrecht - Joseph Haydnlaan
# 14   51.5790    5.22727                             Oisterwijk
# 15   52.3904    5.25068                                 Almere
# 16   52.1516    5.35101                             Amersfoort
# 17   52.0312    5.39909                                Leersum
# 18   52.3356    5.62775                             Harderwijk
# 19   51.2908    5.62967                      Budel-Cranendonck
# 20   53.2754    5.64066                      Sint Annaparochie
# 21   53.0416    5.65750                                  Sneek
# 22   51.2462    5.68886                                  Weert
# 23   51.9727    5.69464                Wageningen - Bosrandweg
# 24   50.8412    5.69759                   Maastricht - Parkweg
# 25   51.9929    5.70888           Wageningen - Keijenbergseweg
# 26   51.7459    5.73039                                  Grave
# 27   52.7625    5.81421                            Luttelgeest
# 28   52.5478    5.84868                                Dronten
# 29   50.9464    5.84884                            Sweikhuizen
# 30   51.9565    5.87144                 Arnhem - Elderhofseweg
# 31   51.8338    5.88090  Nijmegen - Dommer van Poldersveldtweg
# 32   51.2165    5.89318                                 Baexem
# 33   52.5413    5.89411                                 Kampen
# 34   51.9521    5.89545             Arnhem-Zuid - Vreedenburgh
# 35   51.9874    5.89587                Arnhem - Frombergstraat
# 36   51.9869    5.90901                Arnhem - Apeldoornseweg
# 37   51.0896    5.91114                                   Echt
# 38   51.5929    5.92697                               Overloon
# 39   53.2024    5.97911                                 Burgum
# 40   50.8525    5.98651                                Heerlen
# 41   53.1186    6.09698                     Drachten - Ringweg
# 42   53.1126    6.13567                  Drachten - Noorderend
# 43   52.2759    6.19879                             Schalkhaar
# 44   52.1511    6.22411                                Zutphen
# 45   52.7264    6.45394                              Hoogeveen
# 46   52.9769    6.56238                                  Assen
# 47   52.5807    6.59166                             Hardenberg
# 48   52.5813    6.58969                             Hardenberg
# 49   52.3759    6.66374              Almelo - Vriezenveenseweg
# 50   52.7918    6.70760                                Zweeloo
# 51   51.9810    6.73012                            Winterswijk
# 52   52.2726    6.80672                                Hengelo
# 53   52.7423    6.85226                                  Emmen
# 54   53.3169    6.90817                               Delfzijl
# 55   52.8860    7.03492                               Ter Apel

# %% [markdown]
# Our database for cuurent locations is ready to use. Now we can move on to plotting these locations.

# %% [markdown]
# ##### Plot the location information on a map

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
import folium # map rendering library

from folium import plugins
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

print('Geolocation, Clustering, Plotting and Map Libraries imported.')
# Out:
# Geolocation, Clustering, Plotting and Map Libraries imported.

# %% [markdown]
# Let's try the geolocator:

# %%
address = 'Emmen'

geolocator = Nominatim(user_agent="AZC explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(location)
print('The geograpical coordinate of ',address,' are {}, {}.'.format(latitude, longitude))
# Out:
# Emmen, Drenthe, Nederland
# The geograpical coordinate of  Emmen  are 52.788937, 6.8939001.

# %%
df_coa_map = folium.Map(location=[df_coa["Latitude"].mean(), df_coa["Longitude"].mean()], zoom_start=7)
mc = MarkerCluster()

for each in range(len(df_coa)):
    popup_info = folium.Popup(df_coa.Name[each], parse_html=True)
    mc.add_child(folium.Marker(location=[df_coa.Latitude[each], df_coa.Longitude[each]], popup=popup_info))

#print (df_coa["Latitude"].mean(), df_coa["Longitude"].mean())    
df_coa_map.add_child(mc)
df_coa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Current Location and Meeting Place

# %% [markdown]
# Now let's set up three groups in different locations. We specified their locations in a seperate csv. This data can be drawn randomly or manipulated later.

# %%
df_cur_loc = pd.read_csv('azc_current_location.csv')
print(df_cur_loc)
# Out:
#    Latitude  Longitude                Name
# 0   51.2908    5.62967   Budel-Cranendonck
# 1   52.1460    4.38730  Wassenaar-Duinrell

# %% [markdown]
# Now it's time to find a middle point distance-wise.

# %%
midpoint_lat=np.mean([df_cur_loc.iloc[0].Latitude,df_cur_loc.iloc[1].Latitude])
midpoint_long=np.mean([df_cur_loc.iloc[0].Longitude,df_cur_loc.iloc[1].Longitude])

print (midpoint_lat,midpoint_long)
# Out:
# 51.7184 5.008485

# %% [markdown]
# Let's see the current points and the midpoint on the map:

# %%
cur_map = folium.Map(location=[midpoint_lat, midpoint_long],\
                     tiles='OpenStreetMap', zoom_start=8)
mc = MarkerCluster()

# current locations
for each in range(len(df_cur_loc)):
    popup_info = folium.Popup(df_cur_loc.Name[each], parse_html=True)
    mc.add_child(folium.Marker(location=[df_cur_loc.Latitude[each], df_cur_loc.Longitude[each]], popup=popup_info))

# add midpoint
popup_info = folium.Popup('Midpoint', parse_html=True)
mc.add_child(folium.Marker(location=[midpoint_lat, midpoint_long], popup=popup_info))
    
cur_map.add_child(mc)
cur_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Foursquare Data to Overcome Transportation

# %% [markdown]
# 'Midpoint' is the point that we will scan around for a public transportation stop. Then after finding the the public transportation point, we can scan for an appropriate meeting point. We can specify the range up to 2 kms.
#
# So below we are looking for a *'bus'* or *'train'* category in foursquare near the midpoint.

# %%
## Set up foursquare credientials
CLIENT_ID = 'M2SDB00WE3N3ZGZSK2SW40QZGQ2BZ1BE1XV10S3NVWYMQLWJ' # Foursquare ID
CLIENT_SECRET = 'SO23NMFS4VAFE05F0K5PHTLBNC3CN5BEHPKCOBTE3KLUTKLU' # Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 5# limit of number of venues returned by Foursquare API, max 10
radius = 10000 # define in m.

neighborhood_name = 'midpoint_center'

Travel_Category='4d4b7105d754a06379d81259' # main category title in foursquare hierarchy
train_station='4bf58dd8d48988d129951735' 
tram_station='52f2ab2ebcbc57f1066b8b51'
metro_station='4bf58dd8d48988d1fd931735'
light_metro_station='4bf58dd8d48988d1fc931735'
bus_station='52f2ab2ebcbc57f1066b8b4f'
bus_terminal='4bf58dd8d48988d1fe931735'
transportation_service='54541b70498ea6ccd0204bff'

Category_id=Travel_Category
url2 = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{} \
    &query={}&categoryId={}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    midpoint_lat, 
    midpoint_long,
    'station', # we are looking for a station actually
    Category_id,
    radius, 
    LIMIT)
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5c5b73206a60717af388fc82'},
#  'response': {'venues': [{'id': '4bb705bf2f70c9b6a83b8630',
#     'name': 'Station De Oost',
#     'location': {'address': 'Ruigrijk',
#      'crossStreet': 'Efteling',
#      'lat': 51.6479959849122,
#      'lng': 5.053964781164498,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.6479959849122,
#        'lng': 5.053964781164498}],
#      'distance': 8442,
#      'postalCode': '5171 KW',
#      'cc': 'NL',
#      'city': 'Kaatsheuvel',
#      'state': 'Noord-Brabant',
#      'country': 'Nederland',
#      'formattedAddress': ['Ruigrijk (Efteling)',
#       '5171 KW Kaatsheuvel',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'shortName': 'Train Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1549497120',
#     'hasPerk': False},
#    {'id': '57527374498ea375bff77d12',
#     'name': 'Stations Taxi Den Bosch',
#     'location': {'address': 'Vivaldistraat 10',
#      'lat': 51.6795,
#      'lng': 5.1391,
#      'labeledLatLngs': [{'label': 'display', 'lat': 51.6795, 'lng': 5.1391}],
#      'distance': 9998,
#      'postalCode': '5151 KH',
#      'cc': 'NL',
#      'city': 'Drunen',
#      'state': 'Noord-Brabant',
#      'country': 'Nederland',
#      'formattedAddress': ['Vivaldistraat 10', '5151 KH Drunen', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d130951735',
#       'name': 'Taxi',
#       'pluralName': 'Taxis',
#       'shortName': 'Taxi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/taxi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1549497120',
#     'hasPerk': False},
#    {'id': '515c3477e4b0acba8fce1f5b',
#     'name': 'Bus 300 naar Tilburg CS',
#     'location': {'crossStreet': 'Busstation Efteling',
#      'lat': 51.65350538581521,
#      'lng': 5.04197359085083,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.65350538581521,
#        'lng': 5.04197359085083}],
#      'distance': 7584,
#      'cc': 'NL',
#      'city': 'Kaatsheuvel',
#      'state': 'Noord-Brabant',
#      'country': 'Nederland',
#      'formattedAddress': ['Busstation Efteling', 'Kaatsheuvel', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1549497120',
#     'hasPerk': False},
#    {'id': '536722ec498e7fb0e464701d',
#     'name': 'bushalte stationsstraat',
#     'location': {'lat': 51.69361917414585,
#      'lng': 5.133655756550896,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.69361917414585,
#        'lng': 5.133655756550896}],
#      'distance': 9064,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#       'name': 'Bus Stop',
#       'pluralName': 'Bus Stops',
#       'shortName': 'Bus Stop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1549497120',
#     'hasPerk': False},
#    {'id': '4cdc07556ad1a0933449ef56',
#     'name': 'Busstation Loon op Zand',
#     'location': {'address': 'Hoge Steenweg',
#      'crossStreet': 'N261 Midden-Brabantweg',
#      'lat': 51.631666493848755,
#      'lng': 5.062519131815365,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.631666493848755,
#        'lng': 5.062519131815365}],
#      'distance': 10350,
#      'cc': 'NL',
#      'city': 'Loon op Zand',
#      'state': 'Noord-Brabant',
#      'country': 'Nederland',
#      'formattedAddress': ['Hoge Steenweg (N261 Midden-Brabantweg)',
#       'Loon op Zand',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1549497120',
#     'hasPerk': False}]}}

# %%
jsum2 = results2['response']['venues']
for i in range(LIMIT):
    print(i,' : ',jsum2[i]['categories'][0]['name'],' - ',jsum2[0]['name'])
# Out:
# 0  :  Train Station  -  Station De Oost
# 1  :  Taxi  -  Station De Oost
# 2  :  Bus Line  -  Station De Oost
# 3  :  Bus Stop  -  Station De Oost
# 4  :  Bus Station  -  Station De Oost

# %%
## There is a train station nearby. We can extract the coordinates.
stat_lat = jsum2[0]['location']['lat']
stat_long = jsum2[0]['location']['lng']
print(jsum2[0]['categories'][0]['name'],'- lat:',stat_lat,', long:',stat_long)
# Out:
# Train Station - lat: 51.6479959849122 , long: 5.053964781164498

# %% [markdown]
# #### Update Middle Point (With Nearest Station)

# %%
cur_map = folium.Map(location=[midpoint_lat, midpoint_long],\
                     tiles='OpenStreetMap', zoom_start=8)
mc = MarkerCluster()

# current locations
for each in range(len(df_cur_loc)):
    popup_info = folium.Popup(df_cur_loc.Name[each], parse_html=True)
    mc.add_child(folium.Marker(location=[df_cur_loc.Latitude[each], df_cur_loc.Longitude[each]], popup=popup_info))

# add midpoint
popup_info = folium.Popup('Midpoint', parse_html=True)
mc.add_child(folium.Marker(location=[midpoint_lat, midpoint_long], popup=popup_info))


# add the station close to midpoint
popup_info = folium.Popup('Station', parse_html=True)
mc.add_child(folium.Marker(location=[stat_lat, stat_long], popup=popup_info))
        
cur_map.add_child(mc)
cur_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We defined the middle point with a transportation asset (train). Our new midpoint is the 'station' and we will explore nearby area within walking range (1 km) for appropriate venues.

# %% [markdown]
# #### Explore Around the Midpoint for Appropriate Venues

# %%
## Set up foursquare credientials
CLIENT_ID = 'M2SDB00WE3N3ZGZSK2SW40QZGQ2BZ1BE1XV10S3NVWYMQLWJ' # Foursquare ID
CLIENT_SECRET = 'SO23NMFS4VAFE05F0K5PHTLBNC3CN5BEHPKCOBTE3KLUTKLU' # Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 50# limit of number of venues returned by Foursquare API, max 10
radius = 1000 # define in m.

url3 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    stat_lat, 
    stat_long,
    radius,
    LIMIT)
print(url3) 
results3 = requests.get(url3).json()
results3
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=M2SDB00WE3N3ZGZSK2SW40QZGQ2BZ1BE1XV10S3NVWYMQLWJ&client_secret=SO23NMFS4VAFE05F0K5PHTLBNC3CN5BEHPKCOBTE3KLUTKLU&v=20180605&ll=51.6479959849122,5.053964781164498&radius=1000&limit=50
# {'meta': {'code': 200, 'requestId': '5c5b7361dd5797192ba74af1'},
#  'response': {'headerLocation': 'Sprang-Capelle',
#   'headerFullLocation': 'Sprang-Capelle',
#   'headerLocationGranularity': 'city',
#   'totalResults': 117,
#   'suggestedBounds': {'ne': {'lat': 51.65699599391221,
#     'lng': 5.068442354430305},
#    'sw': {'lat': 51.63899597591219, 'lng': 5.039487207898691}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d31889798336dcb752219f0',
#        'name': 'Joris en de Draak',
#        'location': {'address': 'Ruigrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64689183165041,
#         'lng': 5.052646100521088,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64689183165041,
#           'lng': 5.052646100521088}],
#         'distance': 152,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Ruigrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d31889798336dcb752219f0-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc1a523abf495214e54c193',
#        'name': 'De Vliegende Hollander',
#        'location': {'address': 'Ruigrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64759270267822,
#         'lng': 5.052390821628113,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64759270267822,
#           'lng': 5.052390821628113}],
#         'distance': 117,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Ruigrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc1a523abf495214e54c193-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53df82c4498e59584bfd8d28',
#        'name': 'Baron 1898',
#        'location': {'address': 'Ruigrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64845894176831,
#         'lng': 5.050979758703199,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64845894176831,
#           'lng': 5.050979758703199}],
#         'distance': 212,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Ruigrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53df82c4498e59584bfd8d28-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba637ecf964a520823c39e3',
#        'name': 'Python',
#        'location': {'address': 'Ruigrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64784594016514,
#         'lng': 5.053575321056501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64784594016514,
#           'lng': 5.053575321056501}],
#         'distance': 31,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Ruigrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba637ecf964a520823c39e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc6a23d42d1b60c2c3f2a13',
#        'name': 'Ruigrijk',
#        'location': {'address': 'Europalaan 1',
#         'crossStreet': 'Efteling',
#         'lat': 51.648047392423585,
#         'lng': 5.053573109015489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.648047392423585,
#           'lng': 5.053573109015489}],
#         'distance': 27,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1 (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc6a23d42d1b60c2c3f2a13-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf9160f8d30d13a46ac0118',
#        'name': "D'Oude Tuffer",
#        'location': {'address': 'Ruigrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64886048420162,
#         'lng': 5.053759437865355,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64886048420162,
#           'lng': 5.053759437865355}],
#         'distance': 97,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Ruigrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf9160f8d30d13a46ac0118-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be55eb4bcef2d7ff9b003e5',
#        'name': 'Halve Maen',
#        'location': {'address': 'Ruigrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64852212974826,
#         'lng': 5.053143409484591,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64852212974826,
#           'lng': 5.053143409484591}],
#         'distance': 81,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Ruigrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be55eb4bcef2d7ff9b003e5-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc089d7f8219c74d3acb110',
#        'name': 'Piraña',
#        'location': {'address': 'Anderrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64717154184207,
#         'lng': 5.048933885918814,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64717154184207,
#           'lng': 5.048933885918814}],
#         'distance': 359,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Anderrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc089d7f8219c74d3acb110-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a72b543f964a52041db1fe3',
#        'name': 'Efteling',
#        'location': {'address': 'Europalaan 1',
#         'lat': 51.64984217183291,
#         'lng': 5.049397945404053,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64984217183291,
#           'lng': 5.049397945404053}],
#         'distance': 376,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d182941735',
#          'name': 'Theme Park',
#          'pluralName': 'Theme Parks',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a72b543f964a52041db1fe3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58ebfa093cccc60cad0916c6',
#        'name': 'Symbolica: Paleis der Fantasie',
#        'location': {'address': 'Fantasierijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64984971411148,
#         'lng': 5.0496941614022814,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64984971411148,
#           'lng': 5.0496941614022814}],
#         'distance': 359,
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Fantasierijk (Efteling)', 'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58ebfa093cccc60cad0916c6-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6b5b7f1f6e1e74e49ee6f7',
#        'name': 'De Blauwe Reiger',
#        'location': {'address': 'Kinderspoor',
#         'crossStreet': 'Efteling',
#         'lat': 51.64970562578014,
#         'lng': 5.053371894487962,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64970562578014,
#           'lng': 5.053371894487962}],
#         'distance': 194,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Kinderspoor (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d182941735',
#          'name': 'Theme Park',
#          'pluralName': 'Theme Parks',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6b5b7f1f6e1e74e49ee6f7-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be3f11ed27a20a19e4c935b',
#        'name': 'Pagode',
#        'location': {'address': 'Reizenrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.65053883974131,
#         'lng': 5.050618647540286,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65053883974131,
#           'lng': 5.050618647540286}],
#         'distance': 365,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Reizenrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be3f11ed27a20a19e4c935b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb705bf2f70c9b6a83b8630',
#        'name': 'Station De Oost',
#        'location': {'address': 'Ruigrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.6479959849122,
#         'lng': 5.053964781164498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.6479959849122,
#           'lng': 5.053964781164498}],
#         'distance': 0,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Ruigrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d129951735',
#          'name': 'Train Station',
#          'pluralName': 'Train Stations',
#          'shortName': 'Train Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb705bf2f70c9b6a83b8630-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc9b4b768f976b022ae5d83',
#        'name': 'Vogel Rok',
#        'location': {'address': 'Europalaan 1',
#         'crossStreet': 'Efteling',
#         'lat': 51.65189641472252,
#         'lng': 5.052049321517397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65189641472252,
#           'lng': 5.052049321517397}],
#         'distance': 453,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1 (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc9b4b768f976b022ae5d83-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f1ad031e4b0a6271858b49f',
#        'name': 'Polles Keuken',
#        'location': {'address': 'Fantasierijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.65026091137513,
#         'lng': 5.048676918348292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65026091137513,
#           'lng': 5.048676918348292},
#          {'label': 'routing',
#           'lat': 51.650186403818275,
#           'lng': 5.048697888851166}],
#         'distance': 443,
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Fantasierijk (Efteling)',
#          'Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f2',
#          'name': 'Creperie',
#          'pluralName': 'Creperies',
#          'shortName': 'Creperie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f1ad031e4b0a6271858b49f-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc98f66937ca59383f8a592',
#        'name': 'Bob',
#        'location': {'address': 'Europalaan 1',
#         'crossStreet': 'Efteling',
#         'lat': 51.64805865588974,
#         'lng': 5.047207276528747,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64805865588974,
#           'lng': 5.047207276528747}],
#         'distance': 466,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1 (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc98f66937ca59383f8a592-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0a25296071a593b413df32',
#        'name': 'Gondoletta',
#        'location': {'address': 'Reizenrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.650521732310985,
#         'lng': 5.051024501963528,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.650521732310985,
#           'lng': 5.051024501963528}],
#         'distance': 346,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Reizenrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0a25296071a593b413df32-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be6b7bc2457a593e710ad15',
#        'name': 'Sprookjesbos',
#        'location': {'address': 'Marerijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.65042998711351,
#         'lng': 5.046881155676098,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65042998711351,
#           'lng': 5.046881155676098}],
#         'distance': 559,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Marerijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be6b7bc2457a593e710ad15-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6e610cf338236a51370a1b',
#        'name': 'Diorama',
#        'location': {'address': 'Marerijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.65093115361336,
#         'lng': 5.0489052940744195,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65093115361336,
#           'lng': 5.0489052940744195}],
#         'distance': 478,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Marerijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c6e610cf338236a51370a1b-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4210cde5e8423553b632d5',
#        'name': 'Aquanura',
#        'location': {'address': 'Anderrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64853496037529,
#         'lng': 5.045330299490341,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64853496037529,
#           'lng': 5.045330299490341}],
#         'distance': 599,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Anderrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4210cde5e8423553b632d5-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcedd7168f976b0d79c6683',
#        'name': 'Fata Morgana',
#        'location': {'address': 'Anderrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64709820776357,
#         'lng': 5.045487284660339,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64709820776357,
#           'lng': 5.045487284660339}],
#         'distance': 594,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Anderrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcedd7168f976b0d79c6683-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1154bef964a5206f7a23e3',
#        'name': 'Efteling Hotel',
#        'location': {'address': 'Horst 31',
#         'lat': 51.65335700893847,
#         'lng': 5.054555663946074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65335700893847,
#           'lng': 5.054555663946074}],
#         'distance': 598,
#         'postalCode': '5171 RA',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Horst 31', '5171 RA Kaatsheuvel', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1154bef964a5206f7a23e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51fcc282498e3aa36b37bf07',
#        'name': 'Carnaval Festivalplein',
#        'location': {'address': 'Efteling',
#         'crossStreet': 'Reizenrijk',
#         'lat': 51.652167851650546,
#         'lng': 5.052037698807722,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.652167851650546,
#           'lng': 5.052037698807722}],
#         'distance': 483,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Efteling (Reizenrijk)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51fcc282498e3aa36b37bf07-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c78e57181bca093198dfb14',
#        'name': 'Spookslot',
#        'location': {'address': 'Anderrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64900990587478,
#         'lng': 5.048294202029932,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64900990587478,
#           'lng': 5.048294202029932}],
#         'distance': 407,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Anderrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c78e57181bca093198dfb14-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4b4719712ac9284b77ae6c',
#        'name': 'Carnaval Festival',
#        'location': {'address': 'Reizenrijk',
#         'lat': 51.652200289445865,
#         'lng': 5.052077492526383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.652200289445865,
#           'lng': 5.052077492526383}],
#         'distance': 485,
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Reizenrijk', 'Kaatsheuvel', 'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4b4719712ac9284b77ae6c-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8a28dd770fb60c9ecfcfc3',
#        'name': 'Efteling Museum',
#        'location': {'address': 'Marerijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.652084235390504,
#         'lng': 5.0496286153793335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.652084235390504,
#           'lng': 5.0496286153793335}],
#         'distance': 544,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Marerijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8a28dd770fb60c9ecfcfc3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be56f4b2457a5939670ab15',
#        'name': 'Carrousel Paleis',
#        'location': {'address': 'Marerijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.65116504409447,
#         'lng': 5.048863429941158,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65116504409447,
#           'lng': 5.048863429941158}],
#         'distance': 498,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Marerijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be56f4b2457a5939670ab15-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5006a209e4b0aba26d7a5152',
#        'name': 'De Eigenheymer',
#        'location': {'address': 'Europalaan 1',
#         'crossStreet': 'Efteling',
#         'lat': 51.64797436472015,
#         'lng': 5.053656375357759,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64797436472015,
#           'lng': 5.053656375357759}],
#         'distance': 21,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1 (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5006a209e4b0aba26d7a5152-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc1c5b9920eb7136e1d1b2c',
#        'name': 'Anton Pieckplein',
#        'location': {'address': 'Marerijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.65227747633682,
#         'lng': 5.048992803757528,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65227747633682,
#           'lng': 5.048992803757528}],
#         'distance': 587,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Marerijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc1c5b9920eb7136e1d1b2c-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d92f1e0b053b60cf85a83cb',
#        'name': 'Roodkapje',
#        'location': {'address': 'Sprookjesbos',
#         'crossStreet': 'Efteling',
#         'lat': 51.64958929758477,
#         'lng': 5.046755403919227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64958929758477,
#           'lng': 5.046755403919227}],
#         'distance': 528,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Sprookjesbos (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d92f1e0b053b60cf85a83cb-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59468b64c97f2842417893b8',
#        'name': 'Wachtruimte 1e Klas',
#        'location': {'address': 'Ruigrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64796746259062,
#         'lng': 5.053781146128357,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64796746259062,
#           'lng': 5.053781146128357}],
#         'distance': 13,
#         'postalCode': '5171 RA',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Ruigrijk (Efteling)',
#          '5171 RA Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59468b64c97f2842417893b8-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e06ae1e4b0a94f5e437fdb',
#        'name': 'Marerijk',
#        'location': {'address': 'Europalaan 1',
#         'crossStreet': 'Efteling',
#         'lat': 51.6522303559246,
#         'lng': 5.04843560713146,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.6522303559246,
#           'lng': 5.04843560713146}],
#         'distance': 606,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1 (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50e06ae1e4b0a94f5e437fdb-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bff8c9be584c92880556e25',
#        'name': 'De Indische Waterlelies',
#        'location': {'address': 'Sprookjesbos',
#         'crossStreet': 'Efteling',
#         'lat': 51.651061710012286,
#         'lng': 5.0465979373547825,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.651061710012286,
#           'lng': 5.0465979373547825}],
#         'distance': 612,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Sprookjesbos (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bff8c9be584c92880556e25-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d51387ebd6ff04de455ef0c',
#        'name': 'De Verse Oogst',
#        'location': {'address': 'Station de Oost',
#         'lat': 51.64794737834577,
#         'lng': 5.053974458746583,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64794737834577,
#           'lng': 5.053974458746583}],
#         'distance': 5,
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Station de Oost', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d51387ebd6ff04de455ef0c-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b938484f964a520c44634e3',
#        'name': 'Droomvlucht',
#        'location': {'address': 'Marerijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.652507039636696,
#         'lng': 5.046173105835898,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.652507039636696,
#           'lng': 5.046173105835898}],
#         'distance': 736,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Marerijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b938484f964a520c44634e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '553b5a71498e0272efd3982a',
#        'name': 'De Verleiding',
#        'location': {'address': 'Europalaan 1',
#         'crossStreet': 'Efteling',
#         'lat': 51.64828665812472,
#         'lng': 5.052327967552167,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64828665812472,
#           'lng': 5.052327967552167}],
#         'distance': 117,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1 (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d117951735',
#          'name': 'Candy Store',
#          'pluralName': 'Candy Stores',
#          'shortName': 'Candy Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-553b5a71498e0272efd3982a-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d74df3494985481b7522f7e',
#        'name': 'Draak Lichtgeraakt',
#        'location': {'address': 'Sprookjesbos',
#         'crossStreet': 'Efteling',
#         'lat': 51.65016248649601,
#         'lng': 5.047207294887611,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65016248649601,
#           'lng': 5.047207294887611}],
#         'distance': 525,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Sprookjesbos (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d74df3494985481b7522f7e-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc3f94a1f6ef43b89ef8870',
#        'name': 'Bar de Gelagkamer',
#        'location': {'address': 'Efteling Hotel',
#         'lat': 51.65346079473402,
#         'lng': 5.0545834990154646,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65346079473402,
#           'lng': 5.0545834990154646}],
#         'distance': 609,
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Efteling Hotel', 'Kaatsheuvel', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc3f94a1f6ef43b89ef8870-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2ae949b0fbc2edac1b914c',
#        'name': 'Jokies Wereld',
#        'location': {'address': 'Reizenrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.65201065865067,
#         'lng': 5.05200936172862,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65201065865067,
#           'lng': 5.05200936172862}],
#         'distance': 466,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Reizenrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d128951735',
#          'name': 'Gift Shop',
#          'pluralName': 'Gift Shops',
#          'shortName': 'Gift Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e2ae949b0fbc2edac1b914c-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf91ea94a67c928ee5a26cf',
#        'name': 'De Hongerige Machinist',
#        'location': {'address': 'Station de Oost',
#         'crossStreet': 'Efteling',
#         'lat': 51.64800723225125,
#         'lng': 5.053786066508617,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64800723225125,
#           'lng': 5.053786066508617}],
#         'distance': 12,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Station de Oost (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf91ea94a67c928ee5a26cf-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf8ff3d508c0f471f003f31',
#        'name': 'Villa Volta',
#        'location': {'address': 'Marerijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.653231154403336,
#         'lng': 5.047477509505546,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.653231154403336,
#           'lng': 5.047477509505546}],
#         'distance': 735,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Marerijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf8ff3d508c0f471f003f31-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be6c58cd4f7c9b631082720',
#        'name': 'De Witte Walvis',
#        'location': {'address': 'Anderrijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.64847801291514,
#         'lng': 5.048763057173139,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64847801291514,
#           'lng': 5.048763057173139}],
#         'distance': 363,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Anderrijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be6c58cd4f7c9b631082720-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd55b37637ba5932a44f670',
#        'name': 'Doornroosje',
#        'location': {'address': 'Sprookjesbos',
#         'crossStreet': 'Efteling',
#         'lat': 51.65089385053918,
#         'lng': 5.047124530744181,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65089385053918,
#           'lng': 5.047124530744181}],
#         'distance': 572,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Sprookjesbos (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd55b37637ba5932a44f670-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50deec06e4b01ebc566d0802',
#        'name': 'IJspaleis',
#        'location': {'address': 'Europalaan 1',
#         'crossStreet': 'Efteling',
#         'lat': 51.65137567481254,
#         'lng': 5.050503562488468,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65137567481254,
#           'lng': 5.050503562488468}],
#         'distance': 445,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1 (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50deec06e4b01ebc566d0802-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55941f63498e860a8b77562f',
#        'name': "'t Melkhuysje",
#        'location': {'address': 'Europalaan 1',
#         'crossStreet': 'Efteling',
#         'lat': 51.64806473802349,
#         'lng': 5.050327013142632,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64806473802349,
#           'lng': 5.050327013142632}],
#         'distance': 251,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Europalaan 1 (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55941f63498e860a8b77562f-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c137cb2a1010f47f1a64a18',
#        'name': 'Sprookjesboom',
#        'location': {'address': 'Sprookjesbos',
#         'crossStreet': 'Efteling',
#         'lat': 51.651747981760764,
#         'lng': 5.046033512986859,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.651747981760764,
#           'lng': 5.046033512986859}],
#         'distance': 688,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Sprookjesbos (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c137cb2a1010f47f1a64a18-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c016b18b45676b03c28e180',
#        'name': 'Villa Pardoes',
#        'location': {'address': 'Eftelingsestraat 3',
#         'lat': 51.64568470085047,
#         'lng': 5.053121707032462,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64568470085047,
#           'lng': 5.053121707032462}],
#         'distance': 263,
#         'postalCode': '5171 RP',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Eftelingsestraat 3',
#          '5171 RP Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d130941735',
#          'name': 'Building',
#          'pluralName': 'Buildings',
#          'shortName': 'Building',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c016b18b45676b03c28e180-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '592a844c112c6c6e0b33b314',
#        'name': 'Vakantiepark Efteling Loonsche Land',
#        'location': {'address': 'Eftelingsestraat 5',
#         'lat': 51.64553861352643,
#         'lng': 5.0474284648013175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.64553861352643,
#           'lng': 5.0474284648013175}],
#         'distance': 527,
#         'postalCode': '5171 RP',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Eftelingsestraat 5',
#          '5171 RP Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'shortName': 'Resort',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-592a844c112c6c6e0b33b314-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6935560e98a59365c82359',
#        'name': 'Raveleijn',
#        'location': {'address': 'Marerijk',
#         'crossStreet': 'Efteling',
#         'lat': 51.65312434879365,
#         'lng': 5.045989278438494,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.65312434879365,
#           'lng': 5.045989278438494}],
#         'distance': 793,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Marerijk (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c6935560e98a59365c82359-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be3f7eed27a20a1465a935b',
#        'name': 'De Trollenkoning',
#        'location': {'address': 'Sprookjesbos',
#         'crossStreet': 'Efteling',
#         'lat': 51.649885769559894,
#         'lng': 5.04579375250916,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.649885769559894,
#           'lng': 5.04579375250916}],
#         'distance': 602,
#         'postalCode': '5171 KW',
#         'cc': 'NL',
#         'city': 'Kaatsheuvel',
#         'state': 'Noord-Brabant',
#         'country': 'Nederland',
#         'formattedAddress': ['Sprookjesbos (Efteling)',
#          '5171 KW Kaatsheuvel',
#          'Nederland']},
#        'categories': [{'id': '5109983191d435c0d71c2bb1',
#          'name': 'Theme Park Ride / Attraction',
#          'pluralName': 'Theme Park Rides/Attractions',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be3f7eed27a20a1465a935b-49'}]}]}}

# %%
jsum3 = results3['response']['groups'][0]['items']
for i in range(LIMIT):
    print(i,' : ',jsum3[i]['venue']['categories'][0]['name'],' - ', jsum3[i]['venue']['name'])
# Out:
# 0  :  Theme Park Ride / Attraction  -  Joris en de Draak
# 1  :  Theme Park Ride / Attraction  -  De Vliegende Hollander
# 2  :  Theme Park Ride / Attraction  -  Baron 1898
# 3  :  Theme Park Ride / Attraction  -  Python
# 4  :  Theme Park Ride / Attraction  -  Ruigrijk
# 5  :  Theme Park Ride / Attraction  -  D'Oude Tuffer
# 6  :  Theme Park Ride / Attraction  -  Halve Maen
# 7  :  Theme Park Ride / Attraction  -  Piraña
# 8  :  Theme Park  -  Efteling
# 9  :  Theme Park Ride / Attraction  -  Symbolica: Paleis der Fantasie
# 10  :  Theme Park  -  De Blauwe Reiger
# 11  :  Theme Park Ride / Attraction  -  Pagode
# 12  :  Train Station  -  Station De Oost
# 13  :  Theme Park Ride / Attraction  -  Vogel Rok
# 14  :  Creperie  -  Polles Keuken
# 15  :  Theme Park Ride / Attraction  -  Bob
# 16  :  Theme Park Ride / Attraction  -  Gondoletta
# 17  :  Theme Park Ride / Attraction  -  Sprookjesbos
# 18  :  Theme Park Ride / Attraction  -  Diorama
# 19  :  Theme Park Ride / Attraction  -  Aquanura
# 20  :  Theme Park Ride / Attraction  -  Fata Morgana
# 21  :  Hotel  -  Efteling Hotel
# 22  :  Plaza  -  Carnaval Festivalplein
# 23  :  Theme Park Ride / Attraction  -  Spookslot
# 24  :  Theme Park Ride / Attraction  -  Carnaval Festival
# 25  :  History Museum  -  Efteling Museum
# 26  :  Sandwich Place  -  Carrousel Paleis
# 27  :  Food Truck  -  De Eigenheymer
# 28  :  Plaza  -  Anton Pieckplein
# 29  :  Theme Park Ride / Attraction  -  Roodkapje
# 30  :  Café  -  Wachtruimte 1e Klas
# 31  :  Theme Park Ride / Attraction  -  Marerijk
# 32  :  Theme Park Ride / Attraction  -  De Indische Waterlelies
# 33  :  Salad Place  -  De Verse Oogst
# 34  :  Theme Park Ride / Attraction  -  Droomvlucht
# 35  :  Candy Store  -  De Verleiding
# 36  :  Theme Park Ride / Attraction  -  Draak Lichtgeraakt
# 37  :  Bar  -  Bar de Gelagkamer
# 38  :  Gift Shop  -  Jokies Wereld
# 39  :  Snack Place  -  De Hongerige Machinist
# 40  :  Theme Park Ride / Attraction  -  Villa Volta
# 41  :  Snack Place  -  De Witte Walvis
# 42  :  Theme Park Ride / Attraction  -  Doornroosje
# 43  :  Playground  -  IJspaleis
# 44  :  Pizza Place  -  't Melkhuysje
# 45  :  Theme Park Ride / Attraction  -  Sprookjesboom
# 46  :  Building  -  Villa Pardoes
# 47  :  Resort  -  Vakantiepark Efteling Loonsche Land
# 48  :  Theater  -  Raveleijn
# 49  :  Theme Park Ride / Attraction  -  De Trollenkoning

# %% [markdown]
# Voila! looks like there are appropriate places for two families with children.
#
# Lastly, let's find the approximate walking distance.
#
# No.12, No.30, No.43, No.44, No.25, No.35, No.27, No.12 - Looks like a good plan to me.

# %%
from geopy.distance import geodesic

Route = [12,30,43,44,25,35,27,12]

routelist_cat=[]
routelist_name=[]
routelist_lat=[]
routelist_long=[]
routelist_dist=[]
for each in Route:
    curr_cat=jsum3[each]['venue']['categories'][0]['name']
    routelist_cat.append (curr_cat)
    curr_name=jsum3[each]['venue']['name']
    routelist_name.append (curr_name)
    curr_lat=jsum3[each]['venue']['location']['lat']
    routelist_lat.append (curr_lat)
    curr_long=jsum3[each]['venue']['location']['lng']
    routelist_long.append (curr_lat)
    
    if each > 1:
        routelist_dist.append(geodesic((curr_lat,\
                                        curr_long),\
                                       ((jsum3[each-1]['venue']['location']['lat']),\
                                        (jsum3[each-1]['venue']['location']['lng']))).meters)

df_route=pd.DataFrame([routelist_cat, routelist_name, routelist_lat, routelist_long,routelist_dist])

# %%
df_route
# Out:
#                  0                    1           2              3  \
# 0    Train Station                 Café  Playground    Pizza Place
# 1  Station De Oost  Wachtruimte 1e Klas   IJspaleis  't Melkhuysje
# 2           51.648               51.648     51.6514        51.6481
# 3           51.648               51.648     51.6514        51.6481
# 4          365.624              518.681      239.93         368.58
#
#                  4              5               6                7
# 0   History Museum    Candy Store      Food Truck    Train Station
# 1  Efteling Museum  De Verleiding  De Eigenheymer  Station De Oost
# 2          51.6521        51.6483          51.648           51.648
# 3          51.6521        51.6483          51.648           51.648
# 4          169.976        633.999         485.871          365.624

# %% [markdown]
# Although the lat/long information and walking distances may differ slightly in this scale, approximate distances (index 4, in meter, distance to next stop) looks ok.

# %% [markdown]
# The next weekend or so, a friend will probably use this information (and this route :)
